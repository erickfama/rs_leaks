# %% [markdown]
# # Patch downloading

# %% [markdown]
# This notebook contains the code to download the training patches. The steps are the followings:
#
# 1. Filter the leak data to only contain leaks that were present in the main distribution pipe.
# 2. Set the coordinates of the leak to the right CRS in order to be compatible with GEE.
# 3. Define the functions for the download task:
#     - `get_image`: Get the collection of images that contains the leak coordinate and were captured before leak repair.
#     - `bands_clip_image`: Select the bands that will be downloaded and the patch size (in meters).
#     - `download_image`: Download and write the patch in the folder named patches_raw.
# 4. Download the patches. Each patch is downloaded in a zip file which contains one tif file per band.

# %%
import pandas as pd
from datetime import timedelta, datetime
import ee
import pyproj
import requests
import winsound

# %%
# Read leak data 
leaks_clean = pd.read_csv("../data/clean/leaks20-22_clean.csv")

# %% [markdown]
# ## Functions to download patches

# %%
# Get image from image collection
def get_image(start, end, poi_leak):
    
    if isinstance(start, str) == False:
        start = str(start)
        end = str(end)
    
    collection = ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")\
    .filterBounds(poi_leak)\
    .filterDate(ee.Date(start), ee.Date(end))\
    .sort("system:time_start", opt_ascending = False)\
    .sort("CLOUDY_PIXEL_PERCENTAGE")

    img = collection.first()

    print("Date of selected image (Sentinel): ", ee.Date(img.get("system:time_start")).format("yyyy-MM-dd").getInfo(),
          "\nSentinel images found:", collection.size().getInfo(),
          "\nCloud %: ", img.get("CLOUDY_PIXEL_PERCENTAGE").getInfo()) 
    
    return img

# %%
# Define the bands to select and the patch size (radius in meters respect to leak point)
def bands_clip_image(image, buffer_size = 100, bands = ["B4", "B3", "B2"]):
    # Clip image
    image = image.clip(poi.buffer(buffer_size).bounds(proj = "EPSG:32613", maxError = 0.001))

    # Select bands
    image = image.select(bands)

    return image

# %%
# Download patch image
def download_image(image, path, date_label):
    url = image.getDownloadURL(
        {
        "scale": 10,
        "crs": "EPSG:32613",
        "fileFormat": "GeoTIFF",
        "maxPixels": 1e13
        }
    )

    r = requests.get(url, allow_redirects = True)
    open(path + "S2" + "_" + date_label + ".zip", "wb").write(r.content)
    print("Download complete")

# %% [markdown]
# ## Functions to estimate LST 10m band

# %%
def get_landsat_images(start, end, poi_leak):

    if isinstance(start, str) == False:
        start = str(start)
        end = str(end)

    selected_Landsat_collection = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")\
                                    .filterBounds(poi_leak)\
                                    .filterDate(ee.Date(start), ee.Date(end))\
                                    .sort("CLOUD_COVER")

    img_landsat = selected_Landsat_collection.first()

    print("Date of selected image (Landsat):", ee.Date(img_landsat.get("system:time_start")).format("yyyy-MM-dd").getInfo(),
        "\nLandsat images found: ", selected_Landsat_collection.size().getInfo(),
        "\nCloud %: ", img_landsat.get("CLOUD_COVER").getInfo())
    
    if selected_Landsat_collection.size().getInfo() == 0:
        print("THERES NO LANDSAT IMAGES FOR THE SELECTED DATES")

    return img_landsat

# %% [markdown]
# $LST_{10m} = \beta_0 + \beta_1 NDVI_{10m} + \beta_2 NDBI_{10m} + \beta_3 NDWI_{10m}$
#
# where:
#
# $\beta_0, \beta_1, \beta_2, \beta_3$ are estimators calculated with the following linear regression model.
#
# $LST_{30m} = \beta_0 + \beta_1 NDVI_{30m} + \beta_2 NDBI_{30m} + \beta_3 NDWI_{30m}$

# %%
# Create compund bands in order to perform linear regression
def lst_regression(landsat_image, sentinel_image, buffer_size, residuals = True):
    ndvi_landsat = landsat_image.normalizedDifference(["SR_B5", "SR_B4"]).rename("ndvi")
    ndwi_landsat = landsat_image.normalizedDifference(["SR_B3", "SR_B5"]).rename("ndwi")
    ndbi_landsat = landsat_image.normalizedDifference(["SR_B6", "SR_B5"]).rename("ndbi")
    lst_landsat_30m = landsat_image.select("ST_B10").rename("Landsat_LST_30m")

    ndvi_sentinel = sentinel_image.normalizedDifference(["B8", "B4"]).rename("s2_ndvi")
    ndwi_sentinel = sentinel_image.normalizedDifference(["B3", "B11"]).rename("s2_ndwi")
    ndbi_sentinel = sentinel_image.normalizedDifference(["B11", "B8"]).rename("s2_ndbi")


    # Linear regression
    bands = ee.Image(1).addBands(ndvi_landsat).addBands(ndbi_landsat).addBands(ndwi_landsat).addBands(lst_landsat_30m).rename(["constant", "ndvi", "ndbi", "ndwi", "lst"])

    img_landsat_regression = bands.reduceRegion(
        reducer = ee.Reducer.linearRegression(4, 1),
        geometry = poi.buffer(buffer_size).bounds(proj = "EPSG:32613", maxError = 0.001),
        scale = 30,
        maxPixels = 1e13
    )

    # Get coefficients of linear regression
    coefList2 = ee.Array(img_landsat_regression.get("coefficients")).toList()
    intercept2 = ee.Image(ee.Number(ee.List(coefList2.get(0)).get(0))).reproject(crs = "EPSG:32613")
    intercept2_list = ee.List(coefList2.get(0)).get(0)
    slopeNDVI2 = ee.Image(ee.Number(ee.List(coefList2.get(1)).get(0))).reproject(crs = "EPSG:32613")
    slopeNDVI2_list =  ee.List(coefList2.get(1)).get(0)
    slopeNDBI2 = ee.Image(ee.Number(ee.List(coefList2.get(2)).get(0))).reproject(crs = "EPSG:32613")
    slopeNDBI2_list =  ee.List(coefList2.get(2)).get(0)
    slopeNDWI2 = ee.Image(ee.Number(ee.List(coefList2.get(3)).get(0))).reproject(crs = "EPSG:32613")
    slopeNDWI2_list =  ee.List(coefList2.get(3)).get(0)

    # Downscale image
    lst_landsat_10m1 = ee.Image(intercept2).add(slopeNDVI2.multiply(ndvi_sentinel)).add(slopeNDBI2.multiply(ndbi_sentinel).add(slopeNDWI2.multiply(ndwi_sentinel)))

    # Create model 
    LST_model = intercept2.add(slopeNDVI2.multiply(ndvi_landsat))\
                .add(slopeNDBI2.multiply(ndbi_landsat))\
                .add(slopeNDWI2.multiply(ndwi_landsat)).clip(poi.buffer(buffer_size).bounds(proj = "EPSG:32613", maxError = 0.001))

    # Get residuals
    residuals = lst_landsat_30m.subtract(LST_model)

    # Define gaussian kernel in order to perform convolution for image smoothness
    gaussian = ee.Kernel.gaussian(radius = 1.5, units = "pixels")

    # Apply convolution 
    residuals_gaussian = residuals.resample("bicubic").convolve(gaussian)

    # Final downscaled image
    lst_landsat_10m_final = ee.Image(intercept2).add(slopeNDVI2.multiply(ndvi_sentinel))\
                                                .add(slopeNDBI2.multiply(ndbi_sentinel)).add(slopeNDWI2.multiply(ndwi_sentinel))

    # Get final downscaled image with residuals
    lst_landsat_10m_final_residuals = lst_landsat_10m_final.add(residuals_gaussian)

    if residuals == True:
        return lst_landsat_10m_final_residuals.clip(poi.buffer(buffer_size).bounds(proj = "EPSG:32613", maxError = 0.001))
    else: 
        return lst_landsat_10m_final.clip(poi.buffer(buffer_size).bounds(proj = "EPSG:32613", maxError = 0.001))

# %%
def add_lst10m_band(sentinel_image, lst_image):
    
    return sentinel_image.addBands(lst_image.rename("LST_10m"))

# %% [markdown]
# ## Automate Download for all the leaks

# %%
# Initialize GEE API
ee.Initialize()

# %%
leaks_clean.columns
# Out:
# Index(['Unnamed: 0', 'id', 'fecha_de_i', 'fecha_fina', 'fechaasign',
#        'fechalegal', 'nombreunid', 'codestado', 'codtrabajo', 'actividad',
#        'barrio', 'com1', 'com2', 'causal', 'orden', 'solicitud', 'cliente',
#        'producto', 'consecruta', 'codruta', 'x', 'y'],
#       dtype='object')

# %% [markdown]
# ### Downloas leak patches

# %%
bands = ["B4", "B3", "B2", "B1", "B5", "B6", "B7", "B8", "B8A", "B9", "B11", "B12", "WVP"]
i = 0
download_path = "../data/patches_raw/leak/"
patch_size = 100
index_progress = []
id = []
sentinel_img_date = []
landsat_img_date = []
date_diff = []
date_diff_leak = []
sentinel_cloud = []
landsat_cloud = []

prev_rep = 0
for rep in [100, 200, 300, 400, 500, 600, 700, 800, 900, 985]:

    for leak in range(prev_rep, rep):
        print("="*100)
        print("Leak index: ", leak)
        date_leak = datetime.strptime(leaks_clean.fechalegal[leak], "%Y-%m-%d").date()
        id_leak = leaks_clean.id[leak]
        id.append(id_leak)
        
        # Dates for patch

        end_date_landsat = date_leak - timedelta(days = 5)
        start_date_landsat = end_date_landsat - timedelta(days = 25)    

        print("Date of leak: ", date_leak)

        if leak == 0:
            previous_end_date = ""

        if previous_end_date == date_leak:
            i += 1
            print("Leak detected at the same date")
        else:
            i = 0

        # Date for zip label
        date_lab = "i" + str(int(id_leak)) + "d" + "_" + str(leaks_clean.fechalegal[leak])[:10] + "_" + str(leak)
    
        # Coords of leaks
        leak_lat_ogcrs = leaks_clean["y"][leak]
        leak_lon_ogcrs = leaks_clean["x"][leak]

        # Transform to degrees
        transformer = pyproj.Transformer.from_crs("epsg:32613", "epsg:4326")
        leak_lon, leak_lat = transformer.transform(leak_lon_ogcrs, leak_lat_ogcrs)

        # Point of leak
        poi = ee.Geometry.Point([leak_lat, leak_lon])
 
        print("Leak coords: ", (leak_lat, leak_lon), "\n")

        # Get sentinel and landsat collection of images according to leak coord 
        img_landsat = get_landsat_images(start = start_date_landsat, end = end_date_landsat, poi_leak = poi)
        landsat_date = ee.Date(img_landsat.get("system:time_start")).format("yyyy-MM-dd").getInfo()
        landsat_date = datetime.strptime(landsat_date, "%Y-%m-%d").date()

        # Sentinel image is selected after using landsat image date in order to get the minimun time between images
        end_date_sentinel = landsat_date
        start_date_sentinel = end_date_sentinel - timedelta(days = 5)    

        img = get_image(start = start_date_sentinel, end = end_date_sentinel, poi_leak = poi)
        sentinel_date = ee.Date(img.get("system:time_start")).format("yyyy-MM-dd").getInfo()
        sentinel_date = datetime.strptime(sentinel_date, "%Y-%m-%d").date()
        
        # Append date of images
        sentinel_img_date.append(sentinel_date)
        landsat_img_date.append(landsat_date)

        # Get difference of days between dates
        date_diff.append(abs(sentinel_date - landsat_date))
        date_diff_leak.append(sentinel_date - date_leak)
        print("Difference between image dates:", abs(sentinel_date - landsat_date))
        print("Difference between date of leak and date of image:" , abs(sentinel_date - date_leak))

        # Append cloud %
        sentinel_cloud.append(img.get("CLOUDY_PIXEL_PERCENTAGE").getInfo())
        landsat_cloud.append(img_landsat.get("CLOUD_COVER").getInfo())

        # Select bands and reduce the hole image to a patch centered on the leak
        img = bands_clip_image(img, buffer_size = patch_size, bands = bands)

        # Estimate lst from landsat image and add its lst band to sentinel image
        lst_image = lst_regression(landsat_image = img_landsat, sentinel_image = img, buffer_size = patch_size, residuals = True)
        img = add_lst10m_band(img, lst_image = lst_image)

        # Download image
        download_image(image = img, path = download_path, date_label = date_lab)

        previous_end_date = date_leak

        index_progress.append(leak)

    print("+"*100)
    print("PATCH DOWNLOAD COMPLETED", "Batch:", rep)
    prev_rep = rep
    winsound.Beep(2000, 1000)
    if prev_rep == 985:
        break
# Out:
# ====================================================================================================
# Leak index:  0
# Date of leak:  2020-01-07
# Leak coords:  (-102.25322875767611, 21.885447715909184)
#
# Date of selected image (Landsat): 2019-12-13
# Landsat images found:  2
# Cloud %:  0.09
# Date of selected image (Sentinel):  2019-12-09
# Sentinel images found: 2
# Cloud %:  0.150207
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 29 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  1
# Date of leak:  2020-01-13
# Leak coords:  (-102.27553239136687, 21.877245545501356)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  2
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 3
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 10 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  2
# Date of leak:  2020-01-15
# Leak coords:  (-102.41360879741895, 21.717590021696104)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  2
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 2
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 12 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  3
# Date of leak:  2020-01-06
# Leak coords:  (-102.25509706207434, 21.85199613383425)
#
# Date of selected image (Landsat): 2019-12-13
# Landsat images found:  2
# Cloud %:  0.09
# Date of selected image (Sentinel):  2019-12-09
# Sentinel images found: 2
# Cloud %:  0.150207
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 28 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  4
# Date of leak:  2020-01-17
# Leak coords:  (-102.25337771935872, 21.884440490545202)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  2
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 3
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 14 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  5
# Date of leak:  2020-01-16
# Leak coords:  (-102.26882442760963, 21.89234843634541)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  2
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 3
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 13 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  6
# Date of leak:  2020-01-17
# Leak coords:  (-102.29438957526546, 21.85062846972009)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  2
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 2
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 14 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  7
# Date of leak:  2020-01-20
# Leak coords:  (-102.28280072861376, 21.88403627824894)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  3
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 3
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 17 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  8
# Date of leak:  2020-01-20
# Leak detected at the same date
# Leak coords:  (-102.27786738636183, 21.875797251534816)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  3
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 3
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 17 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  9
# Date of leak:  2020-01-21
# Leak coords:  (-102.27659882192091, 21.86711277312892)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  3
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 3
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 18 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  10
# Date of leak:  2020-01-21
# Leak detected at the same date
# Leak coords:  (-102.31222339788508, 21.921890297105698)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  3
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 3
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 18 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  11
# Date of leak:  2020-01-24
# Leak coords:  (-102.27505334665985, 21.867914703745097)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  3
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 3
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 21 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  12
# Date of leak:  2020-01-28
# Leak coords:  (-102.2349450624084, 21.85341979600919)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  4
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 2
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 25 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  13
# Date of leak:  2020-01-28
# Leak detected at the same date
# Leak coords:  (-102.20915497434102, 21.860740886990666)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  4
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 3
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 25 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  14
# Date of leak:  2020-01-29
# Leak coords:  (-102.25373499927287, 21.882846929129766)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  3
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 3
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 26 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  15
# Date of leak:  2020-01-30
# Leak coords:  (-102.26150360040599, 21.897507354910736)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  3
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 3
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  16
# Date of leak:  2020-02-04
# Leak coords:  (-102.27966366874352, 21.871183334413004)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  3
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 3
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 32 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  17
# Date of leak:  2020-02-06
# Leak coords:  (-102.27746524486304, 21.921528245963035)
#
# Date of selected image (Landsat): 2020-01-21
# Landsat images found:  3
# Cloud %:  4.47
# Date of selected image (Sentinel):  2020-01-20
# Sentinel images found: 2
# Cloud %:  30.298976
# Difference between image dates: 1 day, 0:00:00
# Difference between date of leak and date of image: 17 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  18
# Date of leak:  2020-01-31
# Leak coords:  (-102.27966366874352, 21.871183334413004)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  3
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 3
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 28 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  19
# Date of leak:  2020-02-04
# Leak coords:  (-102.26727500243453, 21.81996022015291)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  3
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 2
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 32 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  20
# Date of leak:  2020-02-04
# Leak detected at the same date
# Leak coords:  (-102.27608232282672, 21.921341897223716)
#
# Date of selected image (Landsat): 2020-01-05
# Landsat images found:  3
# Cloud %:  1.89
# Date of selected image (Sentinel):  2020-01-03
# Sentinel images found: 3
# Cloud %:  0.055907
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 32 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  21
# Date of leak:  2020-02-05
# Leak coords:  (-102.25917504207048, 21.930340241171468)
#
# Date of selected image (Landsat): 2020-01-21
# Landsat images found:  3
# Cloud %:  4.47
# Date of selected image (Sentinel):  2020-01-20
# Sentinel images found: 2
# Cloud %:  30.298976
# Difference between image dates: 1 day, 0:00:00
# Difference between date of leak and date of image: 16 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  22
# Date of leak:  2020-02-20
# Leak coords:  (-102.26792286945945, 21.87757392359327)
#
# Date of selected image (Landsat): 2020-02-06
# Landsat images found:  3
# Cloud %:  0.16
# Date of selected image (Sentinel):  2020-02-04
# Sentinel images found: 1
# Cloud %:  70.303065
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 16 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  23
# Date of leak:  2020-02-22
# Leak coords:  (-102.30295983454526, 21.859143309011987)
#
# Date of selected image (Landsat): 2020-02-06
# Landsat images found:  3
# Cloud %:  0.16
# Date of selected image (Sentinel):  2020-02-04
# Sentinel images found: 1
# Cloud %:  70.303065
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 18 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  24
# Date of leak:  2020-02-28
# Leak coords:  (-102.24072803578964, 21.849791603234387)
#
# Date of selected image (Landsat): 2020-02-06
# Landsat images found:  4
# Cloud %:  0.16
# Date of selected image (Sentinel):  2020-02-04
# Sentinel images found: 1
# Cloud %:  70.303065
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 24 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  25
# Date of leak:  2020-02-19
# Leak coords:  (-102.24599943956358, 21.85041383285986)
#
# Date of selected image (Landsat): 2020-02-06
# Landsat images found:  3
# Cloud %:  0.16
# Date of selected image (Sentinel):  2020-02-04
# Sentinel images found: 1
# Cloud %:  70.303065
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  26
# Date of leak:  2020-03-05
# Leak coords:  (-102.23603038150429, 21.868079511246183)
#
# Date of selected image (Landsat): 2020-02-06
# Landsat images found:  3
# Cloud %:  0.16
# Date of selected image (Sentinel):  2020-02-04
# Sentinel images found: 1
# Cloud %:  70.303065
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 30 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  27
# Date of leak:  2020-03-07
# Leak coords:  (-102.23559151196622, 21.871597786698185)
#
# Date of selected image (Landsat): 2020-02-06
# Landsat images found:  3
# Cloud %:  0.16
# Date of selected image (Sentinel):  2020-02-04
# Sentinel images found: 1
# Cloud %:  70.303065
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 32 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  28
# Date of leak:  2020-02-28
# Leak coords:  (-102.25393744048068, 21.889647791209388)
#
# Date of selected image (Landsat): 2020-02-06
# Landsat images found:  4
# Cloud %:  0.16
# Date of selected image (Sentinel):  2020-02-04
# Sentinel images found: 1
# Cloud %:  70.303065
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 24 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  29
# Date of leak:  2020-03-04
# Leak coords:  (-102.26409075630787, 21.853103884323044)
#
# Date of selected image (Landsat): 2020-02-06
# Landsat images found:  3
# Cloud %:  0.16
# Date of selected image (Sentinel):  2020-02-04
# Sentinel images found: 1
# Cloud %:  70.303065
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 29 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  30
# Date of leak:  2020-03-18
# Leak coords:  (-102.30971594667498, 21.87877234484852)
#
# Date of selected image (Landsat): 2020-03-02
# Landsat images found:  3
# Cloud %:  0.02
# Date of selected image (Sentinel):  2020-02-27
# Sentinel images found: 2
# Cloud %:  0.070912
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 20 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  31
# Date of leak:  2020-03-07
# Leak coords:  (-102.26035662335087, 21.910914380354864)
#
# Date of selected image (Landsat): 2020-02-06
# Landsat images found:  3
# Cloud %:  0.16
# Date of selected image (Sentinel):  2020-02-04
# Sentinel images found: 1
# Cloud %:  70.303065
# Difference between image dates: 2 days, 0:00:00
# Difference between date of leak and date of image: 32 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  32
# Date of leak:  2020-03-18
# Leak coords:  (-102.3074738522117, 21.87144635075001)
#
# Date of selected image (Landsat): 2020-03-02
# Landsat images found:  3
# Cloud %:  0.02
# Date of selected image (Sentinel):  2020-02-27
# Sentinel images found: 2
# Cloud %:  0.070912
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 20 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  33
# Date of leak:  2020-03-19
# Leak coords:  (-102.25148914861052, 21.885435488362976)
#
# Date of selected image (Landsat): 2020-03-02
# Landsat images found:  3
# Cloud %:  0.02
# Date of selected image (Sentinel):  2020-02-27
# Sentinel images found: 2
# Cloud %:  0.070912
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 21 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  34
# Date of leak:  2020-03-26
# Leak coords:  (-102.27388126708026, 21.800883177447933)
#
# Date of selected image (Landsat): 2020-03-02
# Landsat images found:  3
# Cloud %:  0.02
# Date of selected image (Sentinel):  2020-02-27
# Sentinel images found: 2
# Cloud %:  0.070912
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 28 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  35
# Date of leak:  2020-03-23
# Leak coords:  (-102.27590098915447, 21.789935679512176)
#
# Date of selected image (Landsat): 2020-03-02
# Landsat images found:  3
# Cloud %:  0.02
# Date of selected image (Sentinel):  2020-02-27
# Sentinel images found: 2
# Cloud %:  0.070912
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 25 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  36
# Date of leak:  2020-03-23
# Leak detected at the same date
# Leak coords:  (-102.27233410763068, 21.87781153911759)
#
# Date of selected image (Landsat): 2020-03-02
# Landsat images found:  3
# Cloud %:  0.02
# Date of selected image (Sentinel):  2020-02-27
# Sentinel images found: 2
# Cloud %:  0.070912
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 25 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  37
# Date of leak:  2020-03-24
# Leak coords:  (-102.27945860110678, 21.862827349146208)
#
# Date of selected image (Landsat): 2020-03-02
# Landsat images found:  3
# Cloud %:  0.02
# Date of selected image (Sentinel):  2020-02-27
# Sentinel images found: 2
# Cloud %:  0.070912
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 26 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  38
# Date of leak:  2020-03-27
# Leak coords:  (-102.25709368119286, 21.860867240102902)
#
# Date of selected image (Landsat): 2020-03-02
# Landsat images found:  3
# Cloud %:  0.02
# Date of selected image (Sentinel):  2020-02-27
# Sentinel images found: 2
# Cloud %:  0.070912
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 29 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  39
# Date of leak:  2020-04-01
# Leak coords:  (-102.30964691444079, 21.866196450209)
#
# Date of selected image (Landsat): 2020-03-25
# Landsat images found:  4
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-20
# Sentinel images found: 2
# Cloud %:  0.13251
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 12 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  40
# Date of leak:  2020-04-01
# Leak detected at the same date
# Leak coords:  (-102.28614417440983, 21.879863122794045)
#
# Date of selected image (Landsat): 2020-03-25
# Landsat images found:  4
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-20
# Sentinel images found: 2
# Cloud %:  0.13251
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 12 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  41
# Date of leak:  2020-03-24
# Leak coords:  (-102.24559642869875, 21.92744206097167)
#
# Date of selected image (Landsat): 2020-03-02
# Landsat images found:  3
# Cloud %:  0.02
# Date of selected image (Sentinel):  2020-02-27
# Sentinel images found: 2
# Cloud %:  0.070912
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 26 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  42
# Date of leak:  2020-04-01
# Leak coords:  (-102.28523710989793, 21.88433905353157)
#
# Date of selected image (Landsat): 2020-03-25
# Landsat images found:  4
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-20
# Sentinel images found: 2
# Cloud %:  0.13251
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 12 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  43
# Date of leak:  2020-04-01
# Leak detected at the same date
# Leak coords:  (-102.28395881694117, 21.88429536894166)
#
# Date of selected image (Landsat): 2020-03-25
# Landsat images found:  4
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-20
# Sentinel images found: 2
# Cloud %:  0.13251
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 12 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  44
# Date of leak:  2020-04-03
# Leak coords:  (-102.24909355615674, 21.87337501498664)
#
# Date of selected image (Landsat): 2020-03-25
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-20
# Sentinel images found: 2
# Cloud %:  0.13251
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 14 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  45
# Date of leak:  2020-04-03
# Leak detected at the same date
# Leak coords:  (-102.2998935601579, 21.870731711465837)
#
# Date of selected image (Landsat): 2020-03-25
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-20
# Sentinel images found: 2
# Cloud %:  0.13251
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 14 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  46
# Date of leak:  2020-04-03
# Leak detected at the same date
# Leak coords:  (-102.28306847080214, 21.92179824881501)
#
# Date of selected image (Landsat): 2020-03-25
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-20
# Sentinel images found: 2
# Cloud %:  0.13251
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 14 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  47
# Date of leak:  2020-04-03
# Leak detected at the same date
# Leak coords:  (-102.28263486890675, 21.921883168917365)
#
# Date of selected image (Landsat): 2020-03-25
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-20
# Sentinel images found: 2
# Cloud %:  0.13251
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 14 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  48
# Date of leak:  2020-04-03
# Leak detected at the same date
# Leak coords:  (-102.27677303858611, 21.867370861358264)
#
# Date of selected image (Landsat): 2020-03-25
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-20
# Sentinel images found: 2
# Cloud %:  0.13251
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 14 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  49
# Date of leak:  2020-04-02
# Leak coords:  (-102.31869319221383, 21.928467445364692)
#
# Date of selected image (Landsat): 2020-03-25
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-20
# Sentinel images found: 2
# Cloud %:  0.13251
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 13 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  50
# Date of leak:  2020-04-03
# Leak coords:  (-102.2571567039324, 21.887382690205406)
#
# Date of selected image (Landsat): 2020-03-25
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-20
# Sentinel images found: 2
# Cloud %:  0.13251
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 14 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  51
# Date of leak:  2020-04-06
# Leak coords:  (-102.31612150517238, 21.928866933000762)
#
# Date of selected image (Landsat): 2020-03-25
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-20
# Sentinel images found: 2
# Cloud %:  0.13251
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 17 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  52
# Date of leak:  2020-04-07
# Leak coords:  (-102.41394855419358, 21.717591323399947)
#
# Date of selected image (Landsat): 2020-03-25
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-20
# Sentinel images found: 2
# Cloud %:  0.13251
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 18 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  53
# Date of leak:  2020-04-14
# Leak coords:  (-102.26486574115926, 21.914180033143783)
#
# Date of selected image (Landsat): 2020-04-03
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-30
# Sentinel images found: 2
# Cloud %:  0.153007
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  54
# Date of leak:  2020-04-14
# Leak detected at the same date
# Leak coords:  (-102.41207965188221, 21.716648385721804)
#
# Date of selected image (Landsat): 2020-04-03
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-30
# Sentinel images found: 2
# Cloud %:  0.153007
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  55
# Date of leak:  2020-04-16
# Leak coords:  (-102.41207965188221, 21.716648385721804)
#
# Date of selected image (Landsat): 2020-04-03
# Landsat images found:  4
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-30
# Sentinel images found: 2
# Cloud %:  0.153007
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 17 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  56
# Date of leak:  2020-04-15
# Leak coords:  (-102.26022317403073, 21.905346813831493)
#
# Date of selected image (Landsat): 2020-04-03
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-30
# Sentinel images found: 2
# Cloud %:  0.153007
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 16 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  57
# Date of leak:  2020-04-20
# Leak coords:  (-102.29824777835121, 21.90058464135094)
#
# Date of selected image (Landsat): 2020-04-03
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-30
# Sentinel images found: 2
# Cloud %:  0.153007
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 21 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  58
# Date of leak:  2020-04-20
# Leak detected at the same date
# Leak coords:  (-102.28159793240418, 21.825258068360785)
#
# Date of selected image (Landsat): 2020-04-03
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-30
# Sentinel images found: 2
# Cloud %:  0.153007
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 21 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  59
# Date of leak:  2020-04-22
# Leak coords:  (-102.27689139222903, 21.790884170041494)
#
# Date of selected image (Landsat): 2020-04-03
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-30
# Sentinel images found: 2
# Cloud %:  0.153007
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 23 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  60
# Date of leak:  2020-04-24
# Leak coords:  (-102.23253991449943, 21.867742991275673)
#
# Date of selected image (Landsat): 2020-04-03
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-30
# Sentinel images found: 2
# Cloud %:  0.153007
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 25 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  61
# Date of leak:  2020-04-25
# Leak coords:  (-102.25583620241942, 21.846509474813445)
#
# Date of selected image (Landsat): 2020-04-03
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-30
# Sentinel images found: 2
# Cloud %:  0.153007
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 26 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  62
# Date of leak:  2020-04-25
# Leak detected at the same date
# Leak coords:  (-102.29935029857593, 21.908406885438545)
#
# Date of selected image (Landsat): 2020-04-03
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-30
# Sentinel images found: 2
# Cloud %:  0.153007
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 26 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  63
# Date of leak:  2020-04-29
# Leak coords:  (-102.26721852781895, 21.86956873252847)
#
# Date of selected image (Landsat): 2020-04-03
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-30
# Sentinel images found: 2
# Cloud %:  0.153007
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 30 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  64
# Date of leak:  2020-04-29
# Leak detected at the same date
# Leak coords:  (-102.2525468460855, 21.91283547348621)
#
# Date of selected image (Landsat): 2020-04-03
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-30
# Sentinel images found: 2
# Cloud %:  0.153007
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 30 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  65
# Date of leak:  2020-04-30
# Leak coords:  (-102.28232626526865, 21.921929592675802)
#
# Date of selected image (Landsat): 2020-04-03
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-30
# Sentinel images found: 2
# Cloud %:  0.153007
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 31 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  66
# Date of leak:  2020-05-02
# Leak coords:  (-102.26730012199245, 21.870589261760397)
#
# Date of selected image (Landsat): 2020-04-03
# Landsat images found:  4
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-30
# Sentinel images found: 2
# Cloud %:  0.153007
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 33 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  67
# Date of leak:  2020-05-02
# Leak detected at the same date
# Leak coords:  (-102.24518717411652, 21.913344505660767)
#
# Date of selected image (Landsat): 2020-04-03
# Landsat images found:  4
# Cloud %:  0
# Date of selected image (Sentinel):  2020-03-30
# Sentinel images found: 2
# Cloud %:  0.153007
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 33 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  68
# Date of leak:  2020-05-05
# Leak coords:  (-102.27855007963065, 21.920750717609057)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 21 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  69
# Date of leak:  2020-05-06
# Leak coords:  (-102.27566507918132, 21.7885030148665)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 22 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  70
# Date of leak:  2020-05-07
# Leak coords:  (-102.27959737191361, 21.939363839851215)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 23 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  71
# Date of leak:  2020-05-06
# Leak coords:  (-102.26022317403073, 21.905346813831493)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 22 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  72
# Date of leak:  2020-05-07
# Leak coords:  (-102.25639042927986, 21.841740416721407)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 23 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  73
# Date of leak:  2020-05-09
# Leak coords:  (-102.24172725133442, 21.864321673906847)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 25 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  74
# Date of leak:  2020-05-08
# Leak coords:  (-102.27959737191361, 21.939363839851215)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 24 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  75
# Date of leak:  2020-05-11
# Leak coords:  (-102.26263160286994, 21.894631834844205)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  76
# Date of leak:  2020-05-30
# Leak coords:  (-102.28078429451776, 21.849584169591473)
#
# Date of selected image (Landsat): 2020-05-12
# Landsat images found:  3
# Cloud %:  0.03
# Date of selected image (Sentinel):  2020-05-07
# Sentinel images found: 2
# Cloud %:  1.951279
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 23 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  77
# Date of leak:  2020-05-11
# Leak coords:  (-102.30988126994745, 21.86562502887131)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  78
# Date of leak:  2020-05-12
# Leak coords:  (-102.2612744187681, 21.92610874542968)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 28 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  79
# Date of leak:  2020-05-12
# Leak detected at the same date
# Leak coords:  (-102.30901145782363, 21.85920744408646)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 28 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  80
# Date of leak:  2020-05-13
# Leak coords:  (-102.31869319221383, 21.928467445364692)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 29 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  81
# Date of leak:  2020-05-13
# Leak detected at the same date
# Leak coords:  (-102.28622381711413, 21.919661009331513)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 29 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  82
# Date of leak:  2020-05-15
# Leak coords:  (-102.2588403726092, 21.904744911204528)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 31 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  83
# Date of leak:  2020-05-15
# Leak detected at the same date
# Leak coords:  (-102.25554525697648, 21.893012379120616)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 31 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  84
# Date of leak:  2020-05-15
# Leak detected at the same date
# Leak coords:  (-102.24319699586023, 21.911487299387808)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 31 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  85
# Date of leak:  2020-05-15
# Leak detected at the same date
# Leak coords:  (-102.25896577968561, 21.904890911839274)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 31 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  86
# Date of leak:  2020-05-15
# Leak detected at the same date
# Leak coords:  (-102.29996571510935, 21.851808811999046)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  3
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 31 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  87
# Date of leak:  2020-05-18
# Leak coords:  (-102.25231606928486, 21.850325537844956)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  4
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 34 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  88
# Date of leak:  2020-05-19
# Leak coords:  (-102.24768056952159, 21.87474483172977)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  4
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 35 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  89
# Date of leak:  2020-05-19
# Leak detected at the same date
# Leak coords:  (-102.26862707864235, 21.87585707353351)
#
# Date of selected image (Landsat): 2020-04-19
# Landsat images found:  4
# Cloud %:  0
# Date of selected image (Sentinel):  2020-04-14
# Sentinel images found: 2
# Cloud %:  0.138309
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 35 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  90
# Date of leak:  2020-05-20
# Leak coords:  (-102.23250005182544, 21.867703673916257)
#
# Date of selected image (Landsat): 2020-05-12
# Landsat images found:  3
# Cloud %:  0.03
# Date of selected image (Sentinel):  2020-05-07
# Sentinel images found: 2
# Cloud %:  1.951279
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 13 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  91
# Date of leak:  2020-05-20
# Leak detected at the same date
# Leak coords:  (-102.30574430556378, 21.90669327967053)
#
# Date of selected image (Landsat): 2020-05-12
# Landsat images found:  3
# Cloud %:  0.03
# Date of selected image (Sentinel):  2020-05-07
# Sentinel images found: 2
# Cloud %:  1.951279
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 13 days, 0:00:00
# Download complete
# ...
# ====================================================================================================
# Leak index:  955
# Date of leak:  2022-11-24
# Leak coords:  (-102.32102716812102, 21.852112900651438)
#
# Date of selected image (Landsat): 2022-11-10
# Landsat images found:  3
# Cloud %:  0.03
# Date of selected image (Sentinel):  2022-11-05
# Sentinel images found: 2
# Cloud %:  0.000874
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 19 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  956
# Date of leak:  2022-11-24
# Leak detected at the same date
# Leak coords:  (-102.26836142885051, 21.922371039374717)
#
# Date of selected image (Landsat): 2022-11-10
# Landsat images found:  3
# Cloud %:  0.03
# Date of selected image (Sentinel):  2022-11-05
# Sentinel images found: 2
# Cloud %:  0.000874
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 19 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  957
# Date of leak:  2022-11-24
# Leak detected at the same date
# Leak coords:  (-102.28430588987717, 21.92792262105508)
#
# Date of selected image (Landsat): 2022-11-10
# Landsat images found:  3
# Cloud %:  0.03
# Date of selected image (Sentinel):  2022-11-05
# Sentinel images found: 2
# Cloud %:  0.000874
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 19 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  958
# Date of leak:  2022-11-25
# Leak coords:  (-102.25582206313143, 21.863659701827128)
#
# Date of selected image (Landsat): 2022-11-10
# Landsat images found:  3
# Cloud %:  0.03
# Date of selected image (Sentinel):  2022-11-05
# Sentinel images found: 2
# Cloud %:  0.000874
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 20 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  959
# Date of leak:  2022-11-28
# Leak coords:  (-102.25887175061453, 21.891185043785214)
#
# Date of selected image (Landsat): 2022-11-10
# Landsat images found:  3
# Cloud %:  0.03
# Date of selected image (Sentinel):  2022-11-05
# Sentinel images found: 2
# Cloud %:  0.000874
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 23 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  960
# Date of leak:  2022-11-30
# Leak coords:  (-102.27414689529907, 21.893787185759134)
#
# Date of selected image (Landsat): 2022-11-10
# Landsat images found:  3
# Cloud %:  0.03
# Date of selected image (Sentinel):  2022-11-05
# Sentinel images found: 2
# Cloud %:  0.000874
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 25 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  961
# Date of leak:  2022-11-30
# Leak detected at the same date
# Leak coords:  (-102.24754689177608, 21.894155785593885)
#
# Date of selected image (Landsat): 2022-11-10
# Landsat images found:  3
# Cloud %:  0.03
# Date of selected image (Sentinel):  2022-11-05
# Sentinel images found: 2
# Cloud %:  0.000874
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 25 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  962
# Date of leak:  2022-12-01
# Leak coords:  (-102.24148408060327, 21.890893572554063)
#
# Date of selected image (Landsat): 2022-11-10
# Landsat images found:  3
# Cloud %:  0.03
# Date of selected image (Sentinel):  2022-11-05
# Sentinel images found: 2
# Cloud %:  0.000874
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 26 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  963
# Date of leak:  2022-12-01
# Leak detected at the same date
# Leak coords:  (-102.27569493914878, 21.857000495984423)
#
# Date of selected image (Landsat): 2022-11-10
# Landsat images found:  3
# Cloud %:  0.03
# Date of selected image (Sentinel):  2022-11-05
# Sentinel images found: 2
# Cloud %:  0.000874
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 26 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  964
# Date of leak:  2022-12-01
# Leak detected at the same date
# Leak coords:  (-102.27614954129095, 21.854335579474345)
#
# Date of selected image (Landsat): 2022-11-10
# Landsat images found:  3
# Cloud %:  0.03
# Date of selected image (Sentinel):  2022-11-05
# Sentinel images found: 2
# Cloud %:  0.000874
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 26 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  965
# Date of leak:  2022-12-02
# Leak coords:  (-102.294641764373, 21.829265790225637)
#
# Date of selected image (Landsat): 2022-11-10
# Landsat images found:  4
# Cloud %:  0.03
# Date of selected image (Sentinel):  2022-11-05
# Sentinel images found: 2
# Cloud %:  0.000874
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  966
# Date of leak:  2022-12-02
# Leak detected at the same date
# Leak coords:  (-102.2764982296, 21.854339776174008)
#
# Date of selected image (Landsat): 2022-11-10
# Landsat images found:  4
# Cloud %:  0.03
# Date of selected image (Sentinel):  2022-11-05
# Sentinel images found: 2
# Cloud %:  0.000874
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  967
# Date of leak:  2022-12-02
# Leak detected at the same date
# Leak coords:  (-102.27643845737985, 21.85433950322247)
#
# Date of selected image (Landsat): 2022-11-10
# Landsat images found:  4
# Cloud %:  0.03
# Date of selected image (Sentinel):  2022-11-05
# Sentinel images found: 2
# Cloud %:  0.000874
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  968
# Date of leak:  2022-12-06
# Leak coords:  (-102.33410278027021, 21.876843362364117)
#
# Date of selected image (Landsat): 2022-11-10
# Landsat images found:  3
# Cloud %:  0.03
# Date of selected image (Sentinel):  2022-11-05
# Sentinel images found: 2
# Cloud %:  0.000874
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 31 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  969
# Date of leak:  2022-12-26
# Leak coords:  (-102.24342048141187, 21.873816220707724)
#
# Date of selected image (Landsat): 2022-12-12
# Landsat images found:  3
# Cloud %:  0.04
# Date of selected image (Sentinel):  2022-12-08
# Sentinel images found: 2
# Cloud %:  1e-05
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 18 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  970
# Date of leak:  2022-12-16
# Leak coords:  (-102.30669097020571, 21.91758192120375)
#
# Date of selected image (Landsat): 2022-12-05
# Landsat images found:  3
# Cloud %:  0.11
# Date of selected image (Sentinel):  2022-11-30
# Sentinel images found: 2
# Cloud %:  0.008292
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 16 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  971
# Date of leak:  2022-12-24
# Leak coords:  (-102.23237637558347, 21.867588090292035)
#
# Date of selected image (Landsat): 2022-12-12
# Landsat images found:  3
# Cloud %:  0.04
# Date of selected image (Sentinel):  2022-12-08
# Sentinel images found: 2
# Cloud %:  1e-05
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 16 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  972
# Date of leak:  2022-12-24
# Leak detected at the same date
# Leak coords:  (-102.26941362243234, 21.81999203397413)
#
# Date of selected image (Landsat): 2022-12-12
# Landsat images found:  3
# Cloud %:  0.04
# Date of selected image (Sentinel):  2022-12-08
# Sentinel images found: 2
# Cloud %:  1e-05
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 16 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  973
# Date of leak:  2022-12-24
# Leak detected at the same date
# Leak coords:  (-102.29063873758726, 21.909353615298595)
#
# Date of selected image (Landsat): 2022-12-12
# Landsat images found:  3
# Cloud %:  0.04
# Date of selected image (Sentinel):  2022-12-08
# Sentinel images found: 2
# Cloud %:  1e-05
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 16 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  974
# Date of leak:  2022-12-20
# Leak coords:  (-102.24798153981575, 21.898990852714316)
#
# Date of selected image (Landsat): 2022-12-12
# Landsat images found:  3
# Cloud %:  0.04
# Date of selected image (Sentinel):  2022-12-08
# Sentinel images found: 2
# Cloud %:  1e-05
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 12 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  975
# Date of leak:  2022-12-20
# Leak detected at the same date
# Leak coords:  (-102.41129355257333, 21.71726718359368)
#
# Date of selected image (Landsat): 2022-12-12
# Landsat images found:  3
# Cloud %:  0.04
# Date of selected image (Sentinel):  2022-12-08
# Sentinel images found: 2
# Cloud %:  1e-05
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 12 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  976
# Date of leak:  2022-12-20
# Leak detected at the same date
# Leak coords:  (-102.4125036731808, 21.717442556865983)
#
# Date of selected image (Landsat): 2022-12-12
# Landsat images found:  3
# Cloud %:  0.04
# Date of selected image (Sentinel):  2022-12-08
# Sentinel images found: 2
# Cloud %:  1e-05
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 12 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  977
# Date of leak:  2022-12-22
# Leak coords:  (-102.31926111503876, 21.852981028220615)
#
# Date of selected image (Landsat): 2022-12-12
# Landsat images found:  3
# Cloud %:  0.04
# Date of selected image (Sentinel):  2022-12-08
# Sentinel images found: 2
# Cloud %:  1e-05
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 14 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  978
# Date of leak:  2022-12-26
# Leak coords:  (-102.23233649095145, 21.867548759170987)
#
# Date of selected image (Landsat): 2022-12-12
# Landsat images found:  3
# Cloud %:  0.04
# Date of selected image (Sentinel):  2022-12-08
# Sentinel images found: 2
# Cloud %:  1e-05
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 18 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  979
# Date of leak:  2022-12-26
# Leak detected at the same date
# Leak coords:  (-102.27937989061991, 21.896363973909278)
#
# Date of selected image (Landsat): 2022-12-12
# Landsat images found:  3
# Cloud %:  0.04
# Date of selected image (Sentinel):  2022-12-08
# Sentinel images found: 2
# Cloud %:  1e-05
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 18 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  980
# Date of leak:  2022-12-27
# Leak coords:  (-102.2820950838443, 21.87077307153964)
#
# Date of selected image (Landsat): 2022-12-12
# Landsat images found:  3
# Cloud %:  0.04
# Date of selected image (Sentinel):  2022-12-08
# Sentinel images found: 2
# Cloud %:  1e-05
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 19 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  981
# Date of leak:  2022-12-27
# Leak detected at the same date
# Leak coords:  (-102.25032708218627, 21.881032456379767)
#
# Date of selected image (Landsat): 2022-12-12
# Landsat images found:  3
# Cloud %:  0.04
# Date of selected image (Sentinel):  2022-12-08
# Sentinel images found: 2
# Cloud %:  1e-05
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 19 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  982
# Date of leak:  2022-12-31
# Leak coords:  (-102.24925440088067, 21.88991734333154)
#
# Date of selected image (Landsat): 2022-12-12
# Landsat images found:  3
# Cloud %:  0.04
# Date of selected image (Sentinel):  2022-12-08
# Sentinel images found: 2
# Cloud %:  1e-05
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 23 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  983
# Date of leak:  2022-12-29
# Leak coords:  (-102.28956070202314, 21.880071804491337)
#
# Date of selected image (Landsat): 2022-12-12
# Landsat images found:  3
# Cloud %:  0.04
# Date of selected image (Sentinel):  2022-12-08
# Sentinel images found: 2
# Cloud %:  1e-05
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 21 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  984
# Date of leak:  2022-12-29
# Leak detected at the same date
# Leak coords:  (-102.26428427432661, 21.853065067944538)
#
# Date of selected image (Landsat): 2022-12-12
# Landsat images found:  3
# Cloud %:  0.04
# Date of selected image (Sentinel):  2022-12-08
# Sentinel images found: 2
# Cloud %:  1e-05
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 21 days, 0:00:00
# Download complete
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# PATCH DOWNLOAD COMPLETED Batch: 985

# %% [markdown]
# ### Download non leak patches

# %%
bands = ["B4", "B3", "B2", "B1", "B5", "B6", "B7", "B8", "B8A", "B9", "B11", "B12", "WVP"]
i = 0
download_path = "../data/patches_raw/non_leak/"
patch_size = 100

index_progress_nonleak = []
id_nonleak = []
sentinel_img_date_nonleak = []
landsat_img_date_nonleak = []
date_diff_nonleak = []
date_diff_leak_nonleak = []
sentinel_cloud_nonleak = []
landsat_cloud_nonleak = []

prev_rep = 0
for rep in [100, 200, 300, 400, 500, 600, 700, 800, 900, 985]:

    for leak in range(prev_rep, rep):
        print("="*100)
        print("Leak index: ", leak)
    
        date_leak = datetime.strptime(leaks_clean.fechalegal[leak], "%Y-%m-%d").date()
        id_leak = leaks_clean.id[leak]
        id_nonleak.append(id_leak)
   
        # Dates for patch after leak
        end_date_landsat = date_leak + timedelta(days = 25)
        start_date_landsat = end_date_landsat - timedelta(days = 20)    
    
        print("Date of leak: ", date_leak)

        if leak == 0:
            previous_end_date = ""

        if previous_end_date == date_leak:
            i += 1
            print("Leak detected at the same date")
        else:
            i = 0

        # Date for zip label
        date_lab = "i" + str(int(id_leak)) + "d" + "_" + str(leaks_clean.fechalegal[leak])[:10] + "_" + str(leak)
    
        # Coords of leaks
        leak_lat_ogcrs = leaks_clean["y"][leak]
        leak_lon_ogcrs = leaks_clean["x"][leak]

        # Transform to degrees
        transformer = pyproj.Transformer.from_crs("epsg:32613", "epsg:4326")
        leak_lon, leak_lat = transformer.transform(leak_lon_ogcrs, leak_lat_ogcrs)

        # Point of leak
        poi = ee.Geometry.Point([leak_lat, leak_lon])
 
        print("Leak coords: ", (leak_lat, leak_lon), "\n")

        # Get sentinel and landsat collection of images according to leak coord 
        img_landsat = get_landsat_images(start = start_date_landsat, end = end_date_landsat, poi_leak = poi)
        landsat_date = ee.Date(img_landsat.get("system:time_start")).format("yyyy-MM-dd").getInfo()
        landsat_date = datetime.strptime(landsat_date, "%Y-%m-%d").date()

        # Sentinel image is selected after using landsat image date in order to get the minimun time between images
        end_date_sentinel = landsat_date
        start_date_sentinel = end_date_sentinel - timedelta(days = 5)    

        img = get_image(start = start_date_sentinel, end = end_date_sentinel, poi_leak = poi)
        sentinel_date = ee.Date(img.get("system:time_start")).format("yyyy-MM-dd").getInfo()
        sentinel_date = datetime.strptime(sentinel_date, "%Y-%m-%d").date()

        # Append date of images
        sentinel_img_date_nonleak.append(sentinel_date)
        landsat_img_date_nonleak.append(landsat_date)
    
        # Get difference of days between dates
        date_diff.append(abs(sentinel_date - landsat_date))
        date_diff_leak.append(sentinel_date - date_leak)
        print("Difference between image dates:", abs(sentinel_date - landsat_date))
        print("Difference between date of leak and date of image:" , abs(sentinel_date - date_leak))

        # Append cloud %
        sentinel_cloud_nonleak.append(img.get("CLOUDY_PIXEL_PERCENTAGE").getInfo())
        landsat_cloud_nonleak.append(img_landsat.get("CLOUD_COVER").getInfo())
    
        # Select bands and reduce the hole image to a patch centered on the leak
        img = bands_clip_image(img, buffer_size = patch_size, bands = bands)

        # Estimate lst from landsat image and add its lst band to sentinel image
        lst_image = lst_regression(landsat_image = img_landsat, sentinel_image = img, buffer_size = patch_size, residuals = True)
        img = add_lst10m_band(img, lst_image = lst_image)

        # Download image
        download_image(image = img, path = download_path, date_label = date_lab)

        previous_end_date = date_leak

    prev_rep = rep
    winsound.Beep(2000, 1000)
    if prev_rep == 985:
        break

# %%
# Add all the info from download to leaks_clean df

leaks_clean["id_download"] = id
leaks_clean["sentinel_img_date"] = sentinel_img_date
leaks_clean["landsat_img_date"] = landsat_img_date
leaks_clean["date_diff_img"] = date_diff
leaks_clean["date_diff_leak"] = date_diff_leak
leaks_clean["sentinel_cloud"] = sentinel_cloud
leaks_clean["landsat_cloud"] = landsat_cloud

#leaks_clean["id_download_nonleak"] = id_nonleak
#leaks_clean["sentinel_img_date_nonleak"] = sentinel_img_date_nonleak
#leaks_clean["landsat_img_date_nonleak"] = landsat_img_date_nonleak
#leaks_clean["date_diff_img_nonleak"] = date_diff_nonleak
#leaks_clean["date_diff_leak_nonleak"] = date_diff_leak_nonleak
#leaks_clean["sentinel_cloud_nonleak"] = sentinel_cloud_nonleak
#leaks_clean["landsat_cloud_nonleak"] = landsat_cloud_nonleak

# %%
leaks_clean.to_csv("../data/clean/leaks_clean.csv")
