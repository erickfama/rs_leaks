# %% [markdown]
# # Patch download - AgSal

# %% [markdown]
# ## Modules

# %%
# Utils
import os
import requests
import winsound
import math

# Data manipulation
import pandas as pd
from datetime import timedelta, datetime

# Google Earth Engine
import ee

# %% [markdown]
# ## Enviromental variables

# %%
DATA_ROOT_PATH = "../data"
LEAKS_46 = DATA_ROOT_PATH + "/raw/agsal_46.xlsx"
LEAKS_49 = DATA_ROOT_PATH + "/raw/agsal_49.xlsx"
SAVE_CLEAN_DATA = DATA_ROOT_PATH + "/clean"

# %% [markdown]
# ## Doc

# %% [markdown]
# ### Functions

# %%
# Get image from image collection
def get_image(start, end, poi_leak):
    
    if isinstance(start, str) == False:
        start = str(start)
        end = str(end)
    
    collection = ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")\
    .filterBounds(poi_leak)\
    .filterDate(ee.Date(start), ee.Date(end))\
    .sort("system:time_start", opt_ascending = False)\
    .sort("CLOUDY_PIXEL_PERCENTAGE")

    img = collection.first()

    print("Date of selected image (Sentinel): ", ee.Date(img.get("system:time_start")).format("yyyy-MM-dd").getInfo(),
          "\nSentinel images found:", collection.size().getInfo(),
          "\nCloud %: ", img.get("CLOUDY_PIXEL_PERCENTAGE").getInfo()) 
    
    return img

# %%
# Define the bands to select and the patch size (radius in meters respect to leak point)
def bands_clip_image(image, buffer_size = 100, bands = ["B4", "B3", "B2"]):
    # Clip image
    image = image.clip(poi.buffer(buffer_size).bounds(proj = "EPSG:32613", maxError = 0.001))

    # Select bands
    image = image.select(bands)

    return image

# %%
# Download patch image
def download_image(image, path, date_label):
    url = image.getDownloadURL(
        {
        "scale": 10,
        "crs": "EPSG:32613",
        "fileFormat": "GeoTIFF",
        "maxPixels": 1e13
        }
    )

    r = requests.get(url, allow_redirects = True)
    open(path + "S2" + "_" + date_label + ".zip", "wb").write(r.content)
    print("Download complete")

# %%
def get_landsat_images(start, end, poi_leak, buffer_regression):

    poi_regression = poi_leak.buffer(buffer_regression).bounds(proj = "EPSG:32613", maxError = 0.001)
 
    try:

        if isinstance(start, str) == False:
            start = str(start)
            end = str(end)
        
        selected_Landsat_collection = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")\
                                        .filterBounds(poi_leak)\
                                        .filterDate(ee.Date(start), ee.Date(end))\
                                        .sort("CLOUD_COVER")

        img_landsat = selected_Landsat_collection.first().clip(poi_regression)

        print("Date of selected image (Landsat):", ee.Date(img_landsat.get("system:time_start")).format("yyyy-MM-dd").getInfo(),
            "\nLandsat images found: ", selected_Landsat_collection.size().getInfo(),
            "\nCloud %: ", img_landsat.get("CLOUD_COVER").getInfo())
    
        if selected_Landsat_collection.size().getInfo() == 0:
            print("THERES NO LANDSAT IMAGES FOR THE SELECTED DATES")
            print("Stopped in rep", rep)

    except:
        start = start + timedelta(days = 5)

        if isinstance(start, str) == False:
            start = str(start)
            end = str(end)

        selected_Landsat_collection = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")\
                                        .filterBounds(poi_leak)\
                                        .filterDate(ee.Date(start), ee.Date(end))\
                                        .sort("CLOUD_COVER")

        img_landsat = selected_Landsat_collection.first().clip(poi_regression)

        print("Date of selected image (Landsat):", ee.Date(img_landsat.get("system:time_start")).format("yyyy-MM-dd").getInfo(),
            "\nLandsat images found: ", selected_Landsat_collection.size().getInfo(),
            "\nCloud %: ", img_landsat.get("CLOUD_COVER").getInfo())
    
        if selected_Landsat_collection.size().getInfo() == 0:
            print("THERES NO LANDSAT IMAGES FOR THE SELECTED DATES")

    return img_landsat

# %%
# Create compund bands in order to perform linear regression
def lst_regression(landsat_image, sentinel_image, poi_leak, buffer_size, buffer_regression = 500, error = True):
    ndvi_landsat = landsat_image.normalizedDifference(["SR_B5", "SR_B4"]).rename("ndvi")
    ndwi_landsat = landsat_image.normalizedDifference(["SR_B3", "SR_B5"]).rename("ndwi")
    ndbi_landsat = landsat_image.normalizedDifference(["SR_B6", "SR_B5"]).rename("ndbi")
    lst_landsat_30m = landsat_image.select("ST_B10").rename("Landsat_LST_30m")

    ndvi_sentinel = sentinel_image.normalizedDifference(["B8", "B4"]).rename("s2_ndvi")
    ndwi_sentinel = sentinel_image.normalizedDifference(["B3", "B11"]).rename("s2_ndwi")
    ndbi_sentinel = sentinel_image.normalizedDifference(["B11", "B8"]).rename("s2_ndbi")

    # Poi for regression, this increases n
    poi_regression = poi_leak.buffer(buffer_regression).bounds(proj = "EPSG:32613", maxError = 0.001)

    # Linear regression
    bands = ee.Image(1).addBands(ndvi_landsat).addBands(ndbi_landsat).addBands(ndwi_landsat).addBands(lst_landsat_30m).rename(["constant", "ndvi", "ndbi", "ndwi", "lst"])

    img_landsat_regression = bands.reduceRegion(
        reducer = ee.Reducer.linearRegression(4, 1),
        geometry = poi_regression,
        scale = 30,
        maxPixels = 1e13
    )

    # Get coefficients of linear regression
    coefList2 = ee.Array(img_landsat_regression.get("coefficients")).toList()
    intercept2 = ee.Image(ee.Number(ee.List(coefList2.get(0)).get(0))).reproject(crs = "EPSG:32613")
    slopeNDVI2 = ee.Image(ee.Number(ee.List(coefList2.get(1)).get(0))).reproject(crs = "EPSG:32613")
    slopeNDBI2 = ee.Image(ee.Number(ee.List(coefList2.get(2)).get(0))).reproject(crs = "EPSG:32613")
    slopeNDWI2 = ee.Image(ee.Number(ee.List(coefList2.get(3)).get(0))).reproject(crs = "EPSG:32613")

    # Predict LST with Landsat info 
    LST_model = intercept2.add(slopeNDVI2.multiply(ndvi_landsat))\
                .add(slopeNDBI2.multiply(ndbi_landsat))\
                .add(slopeNDWI2.multiply(ndwi_landsat))

    # Get residuals
    residuals = lst_landsat_30m.subtract(LST_model)

    # Predict LST with Sentinel info (downscaled image)
    lst_landsat_10m_final = ee.Image(intercept2).add(slopeNDVI2.multiply(ndvi_sentinel))\
                                                .add(slopeNDBI2.multiply(ndbi_sentinel)).add(slopeNDWI2.multiply(ndwi_sentinel))\
                                                .clip(poi_leak.buffer(buffer_size).bounds(proj = "EPSG:32613", maxError = 0.001))

    if error == True:
        
        # Compute number of pixels in the image (n)
        n = landsat_image.select("ST_B10").reduceRegion(
            reducer = ee.Reducer.count(),
            scale = 30,
            maxPixels = 1e13
        ).getInfo()["ST_B10"]

        # Compute Root Mean Squared Error
        rmse = math.sqrt(residuals.select("Landsat_LST_30m").pow(2).reduceRegion(
            reducer = ee.Reducer.sum(),
            scale = 30,
            maxPixels = 1e13
        ).getInfo()["Landsat_LST_30m"]/n)

    return (lst_landsat_10m_final, rmse)

# %%
def add_lst10m_band(sentinel_image, lst_image):
    
    return sentinel_image.addBands(lst_image.rename("LST_10m"))

# %% [markdown]
# ### Variables

# %%
important_raw_columns = ["NO. ORDEN", "FECHA DE CREACION", "FECHA TERMINACION", "TIPO DE ORDEN", "LATITUD", "LONGITUD"]
rename_raw_columns = {"NO. ORDEN": "id", 
                      "FECHA DE CREACION": "fecha_de_i",
                      "FECHA TERMINACION": "fechalegal",
                      "TIPO DE ORDEN": "tipo",
                      "LONGITUD": "x",
                      "LATITUD": "y"}

date_format = "%d-%m-%Y %H:%M:%S"

# Patch download
bands = ["B4", "B3", "B2", "B1", "B5", "B6", "B7", "B8", "B8A", "B9", "B11", "B12", "WVP"]
i = 0
download_path = DATA_ROOT_PATH + "/patches_raw_agsal/leak/"
patch_size = 100
index_progress = []
id = []
sentinel_img_date = []
landsat_img_date = []
date_diff = []
date_diff_leak = []
sentinel_cloud = []
landsat_cloud = []
rmse = []

# %% [markdown]
# ### Load data

# %%
leaks_46_raw = pd.read_excel(LEAKS_46)
leaks_49_raw = pd.read_excel(LEAKS_49)

# %% [markdown]
# ### EDA

# %%
leaks_46_raw.shape
# Out:
# (2030, 22)

# %%
leaks_46_raw["TIPO DE ORDEN"].value_counts()
# Out:
# FC.FUGA EN CALLE          843
# FB.FUGA EN BANQUETA       461
# FP.FUGA EN PIE DERECHO    235
# TE.TRABAJOS ESPECIALES    228
# TB.TUBO ROTO              208
# CT.CAMBIO DE TOMA          55
# Name: TIPO DE ORDEN, dtype: int64

# %%
leaks_49_raw.shape
# Out:
# (2176, 18)

# %%
leaks_49_raw["TIPO DE ORDEN"].value_counts()
# Out:
# FC.FUGA EN CALLE          1085
# FB.FUGA EN BANQUETA        555
# TB.TUBO ROTO               242
# TE.TRABAJOS ESPECIALES     145
# FP.FUGA EN PIE DERECHO      93
# CT.CAMBIO DE TOMA           51
# FL.FUGA NO VISIBLE           5
# Name: TIPO DE ORDEN, dtype: int64

# %%
leaks_46_raw
# Out:
#    NO. ORDEN    FECHA DE CREACION  QUEJA AQUACIS    FECHA  ASIGNACION  \
# 0    2505520  18/12/2023 14:50:44      2469457.0  20/12/2023 10:35:44
# 1    2505513  18/12/2023 14:42:55      2469451.0  20/12/2023 08:36:06
# 2    2505512  18/12/2023 14:42:55      2469450.0  20/12/2023 16:36:58
# 3    2505509  18/12/2023 14:38:48      2469444.0  20/12/2023 08:36:43
# 4    2501253  12/12/2023 12:28:43      2468338.0  13/12/2023 11:35:44
#
#     FECHA  REALIZACION    FECHA TERMINACION               AREA     ZONA   \
# 0  20/12/2023 12:44:22  16/01/2024 12:59:05  EFICIENCIA FISICA   ORIENTE
# 1  20/12/2023 12:26:16  16/01/2024 12:58:41  EFICIENCIA FISICA   ORIENTE
# 2  27/12/2023 15:47:00  16/01/2024 12:57:35  EFICIENCIA FISICA   ORIENTE
# 3  20/12/2023 12:28:49  16/01/2024 12:57:07  EFICIENCIA FISICA   ORIENTE
# 4  20/12/2023 11:42:28  16/01/2024 12:38:31  EFICIENCIA FISICA  PONIENTE
#
#              BRIGADA  NUMERO CONTRATO MARCO  ...                    CLIENTE  \
# 0      BR JUAN GOMEZ           4.600001e+09  ...           7-ELEVEN MEXICO
# 1      BR JUAN GOMEZ           4.600001e+09  ...    MOISES HERNANDEZ VALDES
# 2  BR JOSE RODRIGUEZ           4.600001e+09  ...  ALFA REYES VDA DEL BOSQUE
# 3      BR JUAN GOMEZ           4.600001e+09  ...      ALBERTO PECINA MORENO
# 4      BR JUAN GOMEZ           4.600001e+09  ...  JOVITA GUTIERREZ AGUILERA
#
#             TIPO DE ORDEN TIPO DE PROYECTO PROYCTO  POZO  CENTRO DE COSTOS  \
# 0  FP.FUGA EN PIE DERECHO              NaN     NaN   NaN             74000
# 1        FC.FUGA EN CALLE              NaN     NaN   NaN             74000
# 2     FB.FUGA EN BANQUETA              NaN     NaN   NaN             74000
# 3  FP.FUGA EN PIE DERECHO              NaN     NaN   NaN             74000
# 4        FC.FUGA EN CALLE              NaN     NaN   NaN             74000
#
#      LATITUD    LONGITUD  TIPO DE ORDEN.1  \
# 0  25.438982 -100.978640              NaN
# 1  25.438315 -100.978401              NaN
# 2  25.454452 -101.009695              NaN
# 3  25.438911 -100.978670              NaN
# 4  25.380674 -101.014129              NaN
#
#                                            DIRECCION
# 0  JOSE MARIA LA FRAGUA         2530      GUANAJU...
# 1        DOLORES HIDALGO 220      GUANAJUATO ORIENTE
# 2               CORTAZAR 114      GUANAJUATO ORIENTE
# 3        DOLORES HIDALGO 124      GUANAJUATO ORIENTE
# 4  PASEO DE LAS BEGONIAS 465      PARQUES DE LA C...
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Transform

# %%
# Select important columns and rename it
leaks_46_clean = leaks_46_raw[important_raw_columns].rename(columns=rename_raw_columns)
leaks_49_clean = leaks_49_raw[important_raw_columns].rename(columns=rename_raw_columns)

# %%
# Extract leak type
leaks_46_clean["tipo_cod"] = leaks_46_clean["tipo"].str.extract("([A-Z]+)(?<=.)")
leaks_49_clean["tipo_cod"] = leaks_49_clean["tipo"].str.extract("([A-Z]+)(?<=.)")

# %%
# Join both dfs
leaks_clean = pd.concat([leaks_46_clean, leaks_49_clean]).drop_duplicates()

# %%
# Fix date format
leaks_clean["fecha_de_i"] = leaks_clean["fecha_de_i"].str.replace("/", "-")
leaks_clean["fechalegal"] = leaks_clean["fechalegal"].str.replace("/", "-")

# %% [markdown]
# #### Save clean dfs

# %%
leaks_46_clean.to_csv(SAVE_CLEAN_DATA + "/agsal_46_clean.csv")
leaks_49_clean.to_csv(SAVE_CLEAN_DATA + "/agsal_49_clean.csv")
leaks_clean.to_csv(SAVE_CLEAN_DATA + "/agsal_full_clean.csv")

# %% [markdown]
# ### Download leak patches

# %%
leaks_clean = pd.read_csv(SAVE_CLEAN_DATA + "/agsal_full_clean.csv").loc[0:99]

# %%
# Create leak type subdirectories inside leak and nonleak
for tipo in leaks_clean["tipo_cod"].unique():
    if os.path.exists(download_path + f"{tipo}"):
        print(f"{tipo} dir exists! Skipping...")
        continue
    else:
        print(f"{tipo} dir does not exists! Making directory at {download_path + tipo}...")
        os.mkdir(download_path + f"{tipo}")
# Out:
# FP dir does not exists! Making directory at ../data/patches_raw_agsal/leak/FP...
# FC dir does not exists! Making directory at ../data/patches_raw_agsal/leak/FC...
# FB dir does not exists! Making directory at ../data/patches_raw_agsal/leak/FB...
# TB dir does not exists! Making directory at ../data/patches_raw_agsal/leak/TB...
# TE dir does not exists! Making directory at ../data/patches_raw_agsal/leak/TE...

# %%
# Initialize GEE API
try:
    ee.Initialize()
except:
    ee.Initialize()
    ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=KgaF1lGSwz5Ijjb1vVb50nebPSAB-9WMjOZiKTDRKqg&tc=ShvyvERUBU-hTMSS2mbS2mc4uc6dxhypBsKSfSyOsFQ&cc=XFaRMUwcXnPF1-iCfinGhk1xo6VK7Khfe6zixXARk3o>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=KgaF1lGSwz5Ijjb1vVb50nebPSAB-9WMjOZiKTDRKqg&tc=ShvyvERUBU-hTMSS2mbS2mc4uc6dxhypBsKSfSyOsFQ&cc=XFaRMUwcXnPF1-iCfinGhk1xo6VK7Khfe6zixXARk3o</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.

# %%
prev_rep = 0
for rep in list(range(25, len(leaks_clean) + 25, 25)):

    for leak in range(prev_rep, rep):
        print("="*100)
        print("Leak index: ", leak)
        date_leak = datetime.strptime(leaks_clean.fechalegal[leak], date_format).date()
        id_leak = leaks_clean.id[leak]
        id.append(id_leak)
        
        # Dates for patch

        end_date_landsat = date_leak - timedelta(days = 5)
        start_date_landsat = end_date_landsat - timedelta(days = 25)    

        print("Date of leak: ", date_leak)

        if leak == 0:
            previous_end_date = ""

        if previous_end_date == date_leak:
            i += 1
            print("Leak detected at the same date")
        else:
            i = 0

        # Date for zip label
        leak_type = leaks_clean.tipo_cod[i]
        print(f"Leak type: {leak_type}")
        date_lab = "i" + str(int(id_leak)) + "d" + "_" + leak_type + "_" + str(leaks_clean.fechalegal[leak])[:10] + "_" + str(leak)
    
        # Coords of leaks
        leak_lon = leaks_clean["y"][leak]
        leak_lat = leaks_clean["x"][leak]

        # Point of leak
        poi = ee.Geometry.Point([leak_lat, leak_lon])
 
        print("Leak coords: ", (leak_lat, leak_lon), "\n")

        # Get sentinel and landsat collection of images according to leak coord 
        img_landsat = get_landsat_images(start = start_date_landsat, end = end_date_landsat, poi_leak = poi, buffer_regression = 500)
        landsat_date = ee.Date(img_landsat.get("system:time_start")).format("yyyy-MM-dd").getInfo()
        landsat_date = datetime.strptime(landsat_date, "%Y-%m-%d").date()

        # Sentinel image is selected after using landsat image date in order to get the minimun time between images
        end_date_sentinel = landsat_date
        start_date_sentinel = end_date_sentinel - timedelta(days = 5)    

        img = get_image(start = start_date_sentinel, end = end_date_sentinel, poi_leak = poi)
        sentinel_date = ee.Date(img.get("system:time_start")).format("yyyy-MM-dd").getInfo()
        sentinel_date = datetime.strptime(sentinel_date, "%Y-%m-%d").date()
        
        # Append date of images
        sentinel_img_date.append(sentinel_date)
        landsat_img_date.append(landsat_date)

        # Get difference of days between dates
        date_diff.append(abs(sentinel_date - landsat_date))
        date_diff_leak.append(sentinel_date - date_leak)
        print("Difference between image dates:", abs(sentinel_date - landsat_date))
        print("Difference between date of leak and date of image:" , abs(sentinel_date - date_leak))

        # Append cloud %
        sentinel_cloud.append(img.get("CLOUDY_PIXEL_PERCENTAGE").getInfo())
        landsat_cloud.append(img_landsat.get("CLOUD_COVER").getInfo())

        # Select bands and reduce the hole image to a patch centered on the leak
        img = bands_clip_image(img, buffer_size = patch_size, bands = bands)

        # Estimate lst from landsat image and add its lst band to sentinel image
        lst_image, rmse_value = lst_regression(landsat_image = img_landsat, sentinel_image = img, poi_leak = poi, buffer_size = patch_size, buffer_regression = 500, error = True)
        rmse.append(rmse_value)
        img = add_lst10m_band(img, lst_image = lst_image)

        # Download image
        download_image(image = img, path = download_path + f"{leak_type}/", date_label = date_lab)

        previous_end_date = date_leak

        index_progress.append(leak)

    print("+"*100)
    print("PATCH DOWNLOAD COMPLETED", "Batch:", rep)
    prev_rep = rep
    winsound.Beep(2000, 1000)
    if prev_rep == 985:
        break
# Out:
# ====================================================================================================
# Leak index:  0
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-100.9786398, 25.4389816)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 3
# Cloud %:  64.525414
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  1
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-100.9784005, 25.4383149)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 3
# Cloud %:  64.525414
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  2
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FB
# Leak coords:  (-101.0096951, 25.4544524)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  3
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FP
# Leak coords:  (-100.9786703, 25.4389114)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 3
# Cloud %:  64.525414
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  4
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-101.0141292, 25.3806735)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  5
# Date of leak:  2024-01-24
# Leak type: FP
# Leak coords:  (-101.0018455, 25.4313705)
#
# Date of selected image (Landsat): 2024-01-09
# Landsat images found:  2
# Cloud %:  24.08
# Date of selected image (Sentinel):  2024-01-04
# Sentinel images found: 2
# Cloud %:  11.317934
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 20 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  6
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-100.9899904, 25.4510718)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  7
# Date of leak:  2023-12-27
# Leak type: FP
# Leak coords:  (-100.9845638, 25.4468105)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  2
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 3
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 22 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  8
# Date of leak:  2024-02-02
# Leak type: FP
# Leak coords:  (-101.0106768, 25.4543048)
#
# Date of selected image (Landsat): 2024-01-25
# Landsat images found:  4
# Cloud %:  2.64
# Date of selected image (Sentinel):  2024-01-24
# Sentinel images found: 2
# Cloud %:  99.346352
# Difference between image dates: 1 day, 0:00:00
# Difference between date of leak and date of image: 9 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  9
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-101.0104974, 25.4543313)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  10
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-101.0096879, 25.4544368)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  11
# Date of leak:  2024-02-09
# Leak type: FP
# Leak coords:  (-101.0174954, 25.4328101)
#
# Date of selected image (Landsat): 2024-01-25
# Landsat images found:  2
# Cloud %:  2.64
# Date of selected image (Sentinel):  2024-01-24
# Sentinel images found: 2
# Cloud %:  99.346352
# Difference between image dates: 1 day, 0:00:00
# Difference between date of leak and date of image: 16 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  12
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-100.9854246, 25.4535641)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 3
# Cloud %:  64.525414
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  13
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-100.9852292, 25.4536965)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 3
# Cloud %:  64.525414
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  14
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FB
# Leak coords:  (-101.0127858, 25.3648767)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  15
# Date of leak:  2024-02-02
# Leak type: FP
# Leak coords:  (-101.0162089, 25.3616905)
#
# Date of selected image (Landsat): 2024-01-25
# Landsat images found:  4
# Cloud %:  2.64
# Date of selected image (Sentinel):  2024-01-24
# Sentinel images found: 2
# Cloud %:  99.346352
# Difference between image dates: 1 day, 0:00:00
# Difference between date of leak and date of image: 9 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  16
# Date of leak:  2024-02-09
# Leak type: FP
# Leak coords:  (-100.9880387, 25.4473538)
#
# Date of selected image (Landsat): 2024-01-25
# Landsat images found:  2
# Cloud %:  2.64
# Date of selected image (Sentinel):  2024-01-24
# Sentinel images found: 3
# Cloud %:  99.346352
# Difference between image dates: 1 day, 0:00:00
# Difference between date of leak and date of image: 16 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  17
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-100.9878652, 25.4474943)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 3
# Cloud %:  64.525414
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  18
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-100.9525243, 25.3934483)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 3
# Cloud %:  64.525414
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  19
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FB
# Leak coords:  (-100.9880914, 25.4469658)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 3
# Cloud %:  64.525414
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  20
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FP
# Leak coords:  (-100.987265, 25.4492216)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 3
# Cloud %:  64.525414
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  21
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-100.9843849, 25.4535725)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 3
# Cloud %:  64.525414
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  22
# Date of leak:  2024-02-09
# Leak type: FP
# Leak coords:  (-100.985116, 25.455398)
#
# Date of selected image (Landsat): 2024-01-25
# Landsat images found:  2
# Cloud %:  2.64
# Date of selected image (Sentinel):  2024-01-24
# Sentinel images found: 3
# Cloud %:  99.346352
# Difference between image dates: 1 day, 0:00:00
# Difference between date of leak and date of image: 16 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  23
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-100.9847566, 25.4548424)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 3
# Cloud %:  64.525414
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  24
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-100.9845965, 25.453996)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 3
# Cloud %:  64.525414
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# PATCH DOWNLOAD COMPLETED Batch: 25
# ====================================================================================================
# Leak index:  25
# Date of leak:  2024-02-09
# Leak type: FP
# Leak coords:  (-100.9524973, 25.3934437)
#
# Date of selected image (Landsat): 2024-01-25
# Landsat images found:  2
# Cloud %:  2.64
# Date of selected image (Sentinel):  2024-01-24
# Sentinel images found: 3
# Cloud %:  99.346352
# Difference between image dates: 1 day, 0:00:00
# Difference between date of leak and date of image: 16 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  26
# Date of leak:  2024-02-02
# Leak type: FP
# Leak coords:  (-100.9835143, 25.4551806)
#
# Date of selected image (Landsat): 2024-01-25
# Landsat images found:  4
# Cloud %:  2.64
# Date of selected image (Sentinel):  2024-01-24
# Sentinel images found: 3
# Cloud %:  99.346352
# Difference between image dates: 1 day, 0:00:00
# Difference between date of leak and date of image: 9 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  27
# Date of leak:  2024-01-24
# Leak type: FP
# Leak coords:  (-100.9843346, 25.4549116)
#
# Date of selected image (Landsat): 2024-01-09
# Landsat images found:  2
# Cloud %:  24.08
# Date of selected image (Sentinel):  2024-01-04
# Sentinel images found: 3
# Cloud %:  11.317934
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 20 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  28
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-101.0018022, 25.4314135)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  29
# Date of leak:  2024-01-24
# Leak type: FP
# Leak coords:  (-100.9945545, 25.4313125)
#
# Date of selected image (Landsat): 2024-01-09
# Landsat images found:  2
# Cloud %:  24.08
# Date of selected image (Sentinel):  2024-01-04
# Sentinel images found: 2
# Cloud %:  11.317934
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 20 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  30
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-100.9977695, 25.4324683)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  31
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-100.9964155, 25.4326512)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  32
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FB
# Leak coords:  (-100.9999938, 25.4333462)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  33
# Date of leak:  2024-01-24
# Leak type: FP
# Leak coords:  (-101.0100308, 25.4553985)
#
# Date of selected image (Landsat): 2024-01-09
# Landsat images found:  2
# Cloud %:  24.08
# Date of selected image (Sentinel):  2024-01-04
# Sentinel images found: 2
# Cloud %:  11.317934
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 20 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  34
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-101.0107589, 25.4542974)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  35
# Date of leak:  2024-01-24
# Leak type: FP
# Leak coords:  (-101.0107105, 25.4547357)
#
# Date of selected image (Landsat): 2024-01-09
# Landsat images found:  2
# Cloud %:  24.08
# Date of selected image (Sentinel):  2024-01-04
# Sentinel images found: 2
# Cloud %:  11.317934
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 20 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  36
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-101.0097525, 25.454187)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  37
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-101.0180196, 25.4319453)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  38
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FB
# Leak coords:  (-101.0178993, 25.4322148)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  39
# Date of leak:  2024-02-02
# Leak type: FP
# Leak coords:  (-101.0105259, 25.4545907)
#
# Date of selected image (Landsat): 2024-01-25
# Landsat images found:  4
# Cloud %:  2.64
# Date of selected image (Sentinel):  2024-01-24
# Sentinel images found: 2
# Cloud %:  99.346352
# Difference between image dates: 1 day, 0:00:00
# Difference between date of leak and date of image: 9 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  40
# Date of leak:  2024-02-09
# Leak type: FP
# Leak coords:  (-101.0108921, 25.4542741)
#
# Date of selected image (Landsat): 2024-01-25
# Landsat images found:  2
# Cloud %:  2.64
# Date of selected image (Sentinel):  2024-01-24
# Sentinel images found: 2
# Cloud %:  99.346352
# Difference between image dates: 1 day, 0:00:00
# Difference between date of leak and date of image: 16 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  41
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-101.0174994, 25.4328038)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  42
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-101.0181219, 25.4334637)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  43
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FB
# Leak coords:  (-101.0172775, 25.4289098)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  44
# Date of leak:  2024-01-24
# Leak type: FP
# Leak coords:  (-101.0121162, 25.3671254)
#
# Date of selected image (Landsat): 2024-01-09
# Landsat images found:  2
# Cloud %:  24.08
# Date of selected image (Sentinel):  2024-01-04
# Sentinel images found: 2
# Cloud %:  11.317934
# Difference between image dates: 5 days, 0:00:00
# Difference between date of leak and date of image: 20 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  45
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-101.0123403, 25.365946)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  46
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-101.0121807, 25.3670226)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  47
# Date of leak:  2023-12-20
# Leak type: FP
# Leak coords:  (-101.0130926, 25.3668537)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  48
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-101.0119308, 25.3684232)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  49
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-101.0126633, 25.3677164)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# PATCH DOWNLOAD COMPLETED Batch: 50
# ====================================================================================================
# Leak index:  50
# Date of leak:  2023-12-20
# Leak type: FP
# Leak coords:  (-101.0136746, 25.3683644)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  51
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-101.0104702, 25.3633385)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  52
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FB
# Leak coords:  (-101.0094948, 25.3643893)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  53
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FP
# Leak coords:  (-101.0107039, 25.3635677)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  54
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-101.0109962, 25.3638447)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  55
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: TB
# Leak coords:  (-101.0104104, 25.3642876)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  56
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: TB
# Leak coords:  (-101.0133341, 25.3648808)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  57
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-101.0141825, 25.3657476)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  58
# Date of leak:  2023-12-20
# Leak type: FP
# Leak coords:  (-101.0145246, 25.365974)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  59
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-101.0006458, 25.3532175)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  60
# Date of leak:  2023-12-20
# Leak type: FP
# Leak coords:  (-101.0006177, 25.3532718)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  61
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-101.0006421, 25.3532215)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  62
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FB
# Leak coords:  (-101.0006468, 25.3532175)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  63
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FP
# Leak coords:  (-101.0006392, 25.3532188)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  64
# Date of leak:  2024-01-19
# Leak type: FP
# Leak coords:  (-101.0006057, 25.3532048)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 30 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  65
# Date of leak:  2023-12-20
# Leak type: FP
# Leak coords:  (-101.0006045, 25.3532019)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  66
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-101.0006023, 25.3532073)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  67
# Date of leak:  2024-02-09
# Leak type: FP
# Leak coords:  (-101.0006899, 25.3532019)
#
# Date of selected image (Landsat): 2024-01-25
# Landsat images found:  2
# Cloud %:  2.64
# Date of selected image (Sentinel):  2024-01-24
# Sentinel images found: 2
# Cloud %:  99.346352
# Difference between image dates: 1 day, 0:00:00
# Difference between date of leak and date of image: 16 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  68
# Date of leak:  2024-01-19
# Leak type: FP
# Leak coords:  (-101.000717, 25.3531966)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 30 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  69
# Date of leak:  2024-02-09
# Leak type: FP
# Leak coords:  (-101.0005652, 25.3532128)
#
# Date of selected image (Landsat): 2024-01-25
# Landsat images found:  2
# Cloud %:  2.64
# Date of selected image (Sentinel):  2024-01-24
# Sentinel images found: 2
# Cloud %:  99.346352
# Difference between image dates: 1 day, 0:00:00
# Difference between date of leak and date of image: 16 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  70
# Date of leak:  2023-12-20
# Leak type: FP
# Leak coords:  (-101.000616, 25.353224)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  71
# Date of leak:  2024-01-19
# Leak type: FP
# Leak coords:  (-101.0006291, 25.353229)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 30 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  72
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-101.0006262, 25.3532282)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  73
# Date of leak:  2023-12-20
# Leak type: FP
# Leak coords:  (-101.0006215, 25.3532298)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  74
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-100.9511321, 25.3938191)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 3
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# PATCH DOWNLOAD COMPLETED Batch: 75
# ====================================================================================================
# Leak index:  75
# Date of leak:  2024-01-19
# Leak type: FP
# Leak coords:  (-100.9511272, 25.393816)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 3
# Cloud %:  64.525414
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 30 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  76
# Date of leak:  2024-02-08
# Leak type: FP
# Leak coords:  (-100.9511197, 25.3937855)
#
# Date of selected image (Landsat): 2024-01-25
# Landsat images found:  4
# Cloud %:  2.64
# Date of selected image (Sentinel):  2024-01-24
# Sentinel images found: 3
# Cloud %:  99.346352
# Difference between image dates: 1 day, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  77
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-101.0119142, 25.3629233)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  78
# Date of leak:  2024-01-16
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-101.0118485, 25.3628041)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  79
# Date of leak:  2024-01-19
# Leak type: FP
# Leak coords:  (-101.0096876, 25.4544397)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 30 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  80
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-101.0096817, 25.4544421)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  81
# Date of leak:  2023-12-20
# Leak type: FP
# Leak coords:  (-101.0059149, 25.3748106)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  82
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-101.0067964, 25.3747629)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  83
# Date of leak:  2023-12-20
# Leak type: FP
# Leak coords:  (-100.9904491, 25.381189)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  84
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-100.9888162, 25.3748127)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  85
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FB
# Leak coords:  (-101.0069682, 25.3749909)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  86
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FP
# Leak coords:  (-101.0006454, 25.3532186)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  87
# Date of leak:  2024-01-18
# Leak type: FP
# Leak coords:  (-101.0006391, 25.3532199)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 2
# Cloud %:  84.011209
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 29 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  88
# Date of leak:  2023-12-20
# Leak type: FP
# Leak coords:  (-101.0006453, 25.3532189)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  89
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-101.0006486, 25.3532274)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  90
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FB
# Leak coords:  (-100.9503681, 25.5336066)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  2
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 3
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  91
# Date of leak:  2024-01-18
# Leak type: FP
# Leak coords:  (-100.9841304, 25.4087047)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 3
# Cloud %:  64.525414
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 29 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  92
# Date of leak:  2024-01-16
# Leak type: FP
# Leak coords:  (-100.9842337, 25.4085573)
#
# Date of selected image (Landsat): 2023-12-24
# Landsat images found:  4
# Cloud %:  8.29
# Date of selected image (Sentinel):  2023-12-20
# Sentinel images found: 3
# Cloud %:  64.525414
# Difference between image dates: 4 days, 0:00:00
# Difference between date of leak and date of image: 27 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  93
# Date of leak:  2023-12-20
# Leak type: FP
# Leak coords:  (-100.9870506, 25.4059415)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 3
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  94
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-100.9841464, 25.3756136)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 3
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  95
# Date of leak:  2024-02-08
# Leak type: FP
# Leak coords:  (-100.9873346, 25.4086874)
#
# Date of selected image (Landsat): 2024-01-25
# Landsat images found:  4
# Cloud %:  2.64
# Date of selected image (Sentinel):  2024-01-24
# Sentinel images found: 3
# Cloud %:  99.346352
# Difference between image dates: 1 day, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  96
# Date of leak:  2023-12-20
# Leak type: FP
# Leak coords:  (-100.9754842, 25.3648031)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 3
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  97
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FC
# Leak coords:  (-100.9806413, 25.3691784)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 3
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  98
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FB
# Leak coords:  (-101.0401607, 25.361888)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ====================================================================================================
# Leak index:  99
# Date of leak:  2023-12-20
# Leak detected at the same date
# Leak type: FP
# Leak coords:  (-101.0055451, 25.39087)
#
# Date of selected image (Landsat): 2023-12-08
# Landsat images found:  3
# Cloud %:  1.77
# Date of selected image (Sentinel):  2023-12-05
# Sentinel images found: 2
# Cloud %:  80.734128
# Difference between image dates: 3 days, 0:00:00
# Difference between date of leak and date of image: 15 days, 0:00:00
# Download complete
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# PATCH DOWNLOAD COMPLETED Batch: 100
